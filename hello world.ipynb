# %%
print ('Hello World')
# Out:
# Hello World

# %%
x='hello world'
print (str.upper(x))
# Out:
# HELLO WORLD

# %%
string='abcdefghijklmnopqrstuvwxyz'
print(string[7],string[4],string[11],string[11],string[14],' ',string[22],string[14],string[17],string[11],string[3])
# Out:
# h e l l o   w o r l d

# %%
first_word='Hello'
last_word='world'
print (first_word+' '+last_word)
# Out:
# Hello world
